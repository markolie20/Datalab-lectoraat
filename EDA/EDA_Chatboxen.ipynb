# %% [markdown]
# ## De data van onze opdrachtgever

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# CSV inladen
df = pd.read_csv(r'data\PD Backend en AI-applicatie – Documentatie en Testdata\Messages.csv')  

# Basisinformatie
print("Aantal berichten:", len(df))
print("Aantal unieke auteurs:", df['authorId'].nunique())
print("Gemiddelde berichtlengte:", df['content'].str.len().mean())

# Histogram van berichtlengtes
plt.figure(figsize=(8,5))
sns.histplot(df['content'].str.len(), bins=20, kde=True)
plt.xlabel("Lengte van berichten")
plt.ylabel("Aantal berichten")
plt.title("Verdeling van berichtlengtes")
plt.show()

# Woordwolk genereren
text = " ".join(df['content'].dropna())
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Woordwolk van berichten")
plt.show()
# Out:
# Aantal berichten: 27
# Aantal unieke auteurs: 11
# Gemiddelde berichtlengte: 328.51851851851853

# %%
df
# Out:
#     authorId                                            content
# 0         61  Stel je vraag vooral, zo help je de experts in...
# 1         87  beste,wat ik me vooral afvraag,is waar de buss...
# 2        129           Is nieuwbouw een optie voor het station?
# 3        110  Wat zijn de consequenties van het (deels) afsl...
# 4        110  Bij verhoogd busplatform naast perron 1-2: hoe...
# 5        110  Er wordt wel gesproken in de diverse ontwerpen...
# 6        110  In verschillende ontwerpen wordt waterberging-...
# 7        109  In alle ontwerpen wordt aangenomen dat de fiet...
# 8        109  In alle ontwerpen blijft de slechte situatie o...
# 9        109  Is in deze fase al voldoende rekening gehouden...
# 10       103  In de eerste bijeenkomst kwam het geheel of ge...
# 11       103  Als je je je enkel zou richten op het reiziger...
# 12       103  Hoe verloopt de afwikkeling van de bussen (con...
# 13       103  Kun je de in de vorige vraag genoemde opstoppi...
# 14       122  In het plan Verhoogd Stadszijde lijkt de inric...
# 15       122  Leiden de nieuwe busroutes over de Albinusdree...
# 16       122  In een deel van de plannen wordt hoogbouw voor...
# 17       117  zijn er plannen om van het station een echt 'l...
# 18       119  Ik lees bij ontwerp 1. ). De voetgangersverbin...
# 19       119  Ontwerp 1 Ik lees niets over supermarkten en d...
# 20       119  Ontwerp 2 Betekent de fietsroute door het mors...
# 21       119  Bij de varianten zal bij de aanleg/bouw jarenl...
# 22       123  Hoe wordt rekening gehouden met de kruising va...
# 23        88  Zijn de passagiersstromen (OV) inzichtelijk vo...
# 24       103  In de varianten LBSP en Hartlijn moeten de bus...
# 25        61  Hoi Wilke, dank voor je vraag! Ik heb 'm doorg...
# 26        61  Thomas geeft aan: "Bij de beoordeling van de v...

# %% [markdown]
# ## Onze eigen gegenereerde data

# %%
df2 = pd.read_csv("..\data\groups\group_0.csv")
df2
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\caspe\AppData\Local\Temp\ipykernel_17756\1363028218.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df2 = pd.read_csv("..\data\groups\group_0.csv")
#                                                   job  \
# 0                                     Systems analyst
# 1                                        Cartographer
# 2                                             Actuary
# 3                                    Location manager
# 4                          Lecturer, higher education
# 5                       Clinical molecular geneticist
# 6                      Chartered certified accountant
# 7                   Sales promotion account executive
# 8                               Aeronautical engineer
# 9                                Engineer, automotive
# 10                                             Artist
# 11                                     Chief of Staff
# 12                                      Art therapist
# 13                               Engineer, automotive
# 14                       IT technical support officer
# 15                                 Theme park manager
# 16                       Administrator, Civil Service
# 17                                          Ecologist
# 18                                 Arts administrator
# 19  Clinical scientist, histocompatibility and imm...
# 20                                       Psychiatrist
# 21                               Engineer, production
# 22            Diplomatic Services operational officer
# 23                                      Warden/ranger
# 24        Psychologist, prison and probation services
# 25                    Sport and exercise psychologist
# 26                                       Tour manager
# 27                                        Tax adviser
#
#                                     name sex   birthdate country_of_origin  \
# 0                           Kyara Oennen   F  1975-09-25           Chinees
# 1                            Guus Briere   M  2009-06-13           Chinees
# 2          Evi van de Kooij-van Grinsven   M  1999-02-24             Turks
# 3                      Ruben Cornelissen   F  1935-01-11           Indiaas
# 4                            Jort Backer   F  1940-12-03        Nederlands
# 5                     Sebastiaan Sarneel   F  1950-11-28        Marokkaans
# 6                         Myrthe Fechant   F  1998-05-31           Chinees
# 7                Jasmijn Cadefau-Peeters   M  1983-10-19        Nederlands
# 8          Boaz van Berkel-van den Broek   M  1968-06-09       Indonesisch
# 9                      Boaz Ruijs-Lankle   F  2020-10-13        Nederlands
# 10                          Alex Janssen   F  2010-05-06        Nederlands
# 11          Noortje Everde-Schuylenborch   M  2015-06-11             Turks
# 12                            Ivy Wright   F  1992-02-14             Duits
# 13           Azra van Haspengouw Hesbaye   F  2022-07-18        Nederlands
# 14                       Dion van Rossum   F  1931-07-14             Pools
# 15                     Bilal van de Plas   F  1918-09-24        Nederlands
# 16                  Juliette van der Wal   F  2019-09-23           Indiaas
# 17              Nova van Beeck Beeckmans   F  1995-01-03           Chinees
# 18                 Joëlle Adelaar-Lankle   M  1966-07-19        Marokkaans
# 19                     Nina de la Fleche   M  1942-10-27           Chinees
# 20  Phileine van Dagsburg-van der Heyden   F  1959-06-21             Turks
# 21                    Sten Mercks-Jeggij   F  1913-06-01        Nederlands
# 22                     Sienna van de Ven   F  1962-06-19           Chinees
# 23               Selena van de Biesenbos   M  1916-04-22             Turks
# 24                          Pippa de Vos   M  1959-01-05           Chinees
# 25                            Bo Huberts   M  1912-05-31        Marokkaans
# 26                          Elena Symons   F  2002-02-28        Nederlands
# 27                            Berend Mol   F  2005-03-18        Marokkaans
#
#    socio_economic_status      household_composition political_orientation  \
# 0                   Laag               Alleenstaand                Rechts
# 1              Gemiddeld  Alleenstaand met kinderen                 Links
# 2                   Laag   Samenwonend met kinderen                Midden
# 3                   Laag   Samenwonend met kinderen                Midden
# 4                   Laag   Samenwonend met kinderen                 Links
# 5                   Laag                Samenwonend                Midden
# 6              Gemiddeld   Samenwonend met kinderen                Midden
# 7                   Hoog               Alleenstaand                Midden
# 8                   Laag   Samenwonend met kinderen                 Links
# 9              Gemiddeld   Samenwonend met kinderen                Midden
# 10                  Laag               Alleenstaand                Midden
# 11             Gemiddeld                Samenwonend                Midden
# 12                  Hoog               Alleenstaand                Midden
# 13                  Laag   Samenwonend met kinderen                Midden
# 14                  Laag               Alleenstaand                Midden
# 15                  Hoog               Alleenstaand                Midden
# 16                  Hoog                Samenwonend                Midden
# 17             Gemiddeld                Samenwonend                Midden
# 18                  Hoog   Samenwonend met kinderen                Midden
# 19             Gemiddeld                Samenwonend                Rechts
# 20                  Laag   Samenwonend met kinderen                 Links
# 21                  Laag                Samenwonend                 Links
# 22             Gemiddeld  Alleenstaand met kinderen                Midden
# 23                  Laag   Samenwonend met kinderen                Midden
# 24                  Hoog               Alleenstaand                Midden
# 25             Gemiddeld   Samenwonend met kinderen                Midden
# 26                  Laag                Samenwonend                 Links
# 27             Gemiddeld                Samenwonend                 Links
#
#    education_level       religion    marital_status employment_status  \
# 0              MBO  Hindoeïstisch            Gehuwd     Gepensioneerd
# 1               WO    Christelijk          Ongehuwd          Fulltime
# 2             HAVO    Christelijk  Weduwe/Weduwnaar       Zelfstandig
# 3             VMBO    Islamitisch          Ongehuwd          Parttime
# 4              MBO   Geen religie            Gehuwd          Parttime
# 5             HAVO    Islamitisch        Gescheiden     Gepensioneerd
# 6              VWO   Geen religie        Gescheiden           Student
# 7              MBO   Geen religie        Gescheiden          Parttime
# 8              MBO   Geen religie            Gehuwd           Student
# 9              MBO    Christelijk            Gehuwd          Parttime
# 10  Basisonderwijs    Christelijk          Ongehuwd          Fulltime
# 11  Basisonderwijs    Islamitisch          Ongehuwd          Fulltime
# 12             MBO         Anders            Gehuwd          Parttime
# 13             HBO    Christelijk          Ongehuwd           Student
# 14            HAVO    Islamitisch          Ongehuwd          Fulltime
# 15             VWO    Islamitisch        Gescheiden          Fulltime
# 16            VMBO    Islamitisch          Ongehuwd       Zelfstandig
# 17             MBO         Anders          Ongehuwd           Student
# 18             MBO    Christelijk          Ongehuwd           Student
# 19            HAVO    Christelijk          Ongehuwd          Werkloos
# 20            HAVO    Christelijk            Gehuwd          Werkloos
# 21            VMBO          Joods          Ongehuwd     Gepensioneerd
# 22             HBO   Geen religie          Ongehuwd          Fulltime
# 23  Basisonderwijs    Christelijk          Ongehuwd          Werkloos
# 24             MBO    Islamitisch            Gehuwd          Parttime
# 25             MBO   Geen religie        Gescheiden          Werkloos
# 26             MBO    Christelijk        Gescheiden          Fulltime
# 27             HBO    Islamitisch        Gescheiden           Student
#
#           housing_type technology_proficiency
# 0          Rijtjeshuis               Advanced
# 1          Rijtjeshuis           Intermediate
# 2          Appartement               Advanced
# 3          Appartement               Advanced
# 4          Appartement                 Expert
# 5          Appartement           Intermediate
# 6          Appartement           Intermediate
# 7          Rijtjeshuis               Beginner
# 8          Appartement                 Expert
# 9          Rijtjeshuis               Advanced
# 10         Rijtjeshuis           Intermediate
# 11         Rijtjeshuis               Beginner
# 12         Rijtjeshuis               Advanced
# 13         Rijtjeshuis               Advanced
# 14          Vrijstaand           Intermediate
# 15         Rijtjeshuis                 Expert
# 16         Rijtjeshuis               Beginner
# 17         Rijtjeshuis                 Expert
# 18  Twee-onder-een-kap               Advanced
# 19         Rijtjeshuis               Beginner
# 20         Rijtjeshuis               Beginner
# 21         Appartement               Beginner
# 22          Vrijstaand               Beginner
# 23         Appartement               Beginner
# 24  Twee-onder-een-kap           Intermediate
# 25         Appartement               Beginner
# 26              Studio               Advanced
# 27         Appartement           Intermediate

# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt

# Pad naar de map met CSV-bestanden
data_folder = r"..\data\groups" 

# Controleer of de map bestaat
if not os.path.exists(data_folder):
    print(f"De map '{data_folder}' bestaat niet.")
else:
    # Lijst de bestanden in de map op
    files = os.listdir(data_folder)
    print(f"Bestanden in de map '{data_folder}':")
    
    # Toon alleen de CSV-bestanden
    csv_files = [f for f in files if f.endswith(".csv")]
    


# Data inlezen en samenvoegen
df_list = [pd.read_csv(os.path.join(data_folder, f)) for f in csv_files]
df = pd.concat(df_list, ignore_index=True)

# Specifieke kolommen selecteren voor analyse
columns_of_interest = [
    'sex', 'socio_economic_status', 'household_composition', 'political_orientation', 
    'education_level', 'religion', 'marital_status', 'employment_status', 
    'housing_type', 'technology_proficiency'
]

df_filtered = df[columns_of_interest]

# Basisinformatie over de gefilterde dataset
print("\nDataset info voor geselecteerde kolommen:")
print(df_filtered.info())

# Bekijk de eerste paar rijen van de gefilterde data
print("\nEerste paar rijen van de geselecteerde data:")
print(df_filtered.head())

# Check voor missende waarden in de gefilterde dataset
print("\nMissende waarden per kolom:")
print(df_filtered.isnull().sum())



# Distributie van categorische kolommen in de gefilterde dataset
categorical_cols = df_filtered.select_dtypes(include=['object']).columns

for col in categorical_cols:
    plt.figure(figsize=(10, 4))
    sns.countplot(y=df_filtered[col], order=df_filtered[col].value_counts().index)
    plt.title(f"Distributie van {col}")
    plt.show()

# Indien je de leeftijd wilt berekenen op basis van birthdate
# Eerst de 'birthdate' kolom toevoegen en de leeftijd berekenen
df['birthdate'] = pd.to_datetime(df['birthdate'], errors='coerce')
df['age'] = (pd.to_datetime('today') - df['birthdate']).dt.days // 365

# Als er een leeftijdkolom is, kun je die toevoegen aan de gefilterde dataset
if 'age' in df.columns:
    df_filtered['age'] = df['age']

# Leeftijdshistogram (indien van toepassing)
if 'age' in df_filtered.columns:
    plt.figure(figsize=(10, 6))
    sns.histplot(df_filtered['age'], bins=30, kde=True)
    plt.title("Leeftijdsdistributie")
    plt.show()
# Out:
# Bestanden in de map '..\data\groups':
#
# Dataset info voor geselecteerde kolommen:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22693 entries, 0 to 22692
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sex                     22693 non-null  object
#  1   socio_economic_status   22693 non-null  object
#  2   household_composition   22693 non-null  object
#  3   political_orientation   22693 non-null  object
#  4   education_level         22693 non-null  object
#  5   religion                22693 non-null  object
#  6   marital_status          22693 non-null  object
#  7   employment_status       22693 non-null  object
#  8   housing_type            22693 non-null  object
#  9   technology_proficiency  22693 non-null  object
# dtypes: object(10)
# memory usage: 1.7+ MB
# None
#
# Eerste paar rijen van de geselecteerde data:
#   sex socio_economic_status      household_composition political_orientation  \
# 0   F                  Laag               Alleenstaand                Rechts
# 1   M             Gemiddeld  Alleenstaand met kinderen                 Links
# 2   M                  Laag   Samenwonend met kinderen                Midden
# 3   F                  Laag   Samenwonend met kinderen                Midden
# 4   F                  Laag   Samenwonend met kinderen                 Links
#
#   education_level       religion    marital_status employment_status  \
# 0             MBO  Hindoeïstisch            Gehuwd     Gepensioneerd
# 1              WO    Christelijk          Ongehuwd          Fulltime
# 2            HAVO    Christelijk  Weduwe/Weduwnaar       Zelfstandig
# 3            VMBO    Islamitisch          Ongehuwd          Parttime
# 4             MBO   Geen religie            Gehuwd          Parttime
#
#   housing_type technology_proficiency
# 0  Rijtjeshuis               Advanced
# 1  Rijtjeshuis           Intermediate
# 2  Appartement               Advanced
# 3  Appartement               Advanced
# 4  Appartement                 Expert
#
# Missende waarden per kolom:
# sex                       0
# socio_economic_status     0
# household_composition     0
# political_orientation     0
# education_level           0
# religion                  0
# marital_status            0
# employment_status         0
# housing_type              0
# technology_proficiency    0
# dtype: int64
# C:\Users\caspe\AppData\Local\Temp\ipykernel_29440\1873735030.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['age'] = df['age']

# %%
df = df['age'].sort_values(ascending=True)
df
# Out:
# 6068       0
# 4239       0
# 7616       0
# 18973      0
# 14248      0
#         ...
# 204      116
# 18401    116
# 21648    116
# 5637     116
# 14294    116
# Name: age, Length: 22693, dtype: int64

# %%
df
# Out:
# 6068       0
# 4239       0
# 7616       0
# 18973      0
# 14248      0
#         ...
# 204      116
# 18401    116
# 21648    116
# 5637     116
# 14294    116
# Name: age, Length: 22693, dtype: int64

# %% [markdown]
# ## Groepen appart

# %%
df_list = []

for f in csv_files:
    group_name = os.path.splitext(f)[0]
    df_tmp = pd.read_csv(os.path.join(data_folder, f))
    df_tmp['group'] = group_name  # Voeg groepsnaam toe als nieuwe kolom
    df_list.append(df_tmp)

df = pd.concat(df_list, ignore_index=True)  # Combineer alles in één dataframe
df
# Out:
#                                                job  \
# 0                                  Systems analyst
# 1                                     Cartographer
# 2                                          Actuary
# 3                                 Location manager
# 4                       Lecturer, higher education
# ...                                            ...
# 22688                      Diagnostic radiographer
# 22689                       Programmer, multimedia
# 22690             Higher education careers adviser
# 22691  Armed forces training and education officer
# 22692                          Seismic interpreter
#
#                                 name sex   birthdate country_of_origin  \
# 0                       Kyara Oennen   F  1975-09-25           Chinees
# 1                        Guus Briere   M  2009-06-13           Chinees
# 2      Evi van de Kooij-van Grinsven   M  1999-02-24             Turks
# 3                  Ruben Cornelissen   F  1935-01-11           Indiaas
# 4                        Jort Backer   F  1940-12-03        Nederlands
# ...                              ...  ..         ...               ...
# 22688                   Yusuf Dubois   F  1924-01-27       Indonesisch
# 22689           Ibrahim van der Leek   F  1966-12-22           Chinees
# 22690   Lena van de Ven-van Engeland   M  1928-09-14        Nederlands
# 22691                 Joost Sterkman   M  1991-05-29        Nederlands
# 22692        Noah Bresse-van Stralen   M  1960-08-29             Turks
#
#       socio_economic_status      household_composition political_orientation  \
# 0                      Laag               Alleenstaand                Rechts
# 1                 Gemiddeld  Alleenstaand met kinderen                 Links
# 2                      Laag   Samenwonend met kinderen                Midden
# 3                      Laag   Samenwonend met kinderen                Midden
# 4                      Laag   Samenwonend met kinderen                 Links
# ...                     ...                        ...                   ...
# 22688                  Laag                Samenwonend                Rechts
# 22689                  Laag   Samenwonend met kinderen                 Links
# 22690             Gemiddeld   Samenwonend met kinderen                Midden
# 22691                  Laag                Samenwonend                Rechts
# 22692                  Hoog   Samenwonend met kinderen                Rechts
#
#       education_level       religion    marital_status employment_status  \
# 0                 MBO  Hindoeïstisch            Gehuwd     Gepensioneerd
# 1                  WO    Christelijk          Ongehuwd          Fulltime
# 2                HAVO    Christelijk  Weduwe/Weduwnaar       Zelfstandig
# 3                VMBO    Islamitisch          Ongehuwd          Parttime
# 4                 MBO   Geen religie            Gehuwd          Parttime
# ...               ...            ...               ...               ...
# 22688             HBO   Geen religie          Ongehuwd          Fulltime
# 22689            HAVO    Islamitisch          Ongehuwd          Parttime
# 22690             MBO    Islamitisch          Ongehuwd          Werkloos
# 22691            VMBO    Christelijk            Gehuwd          Parttime
# 22692             MBO  Boeddhistisch            Gehuwd          Fulltime
#
#       housing_type technology_proficiency      group
# 0      Rijtjeshuis               Advanced    group_0
# 1      Rijtjeshuis           Intermediate    group_0
# 2      Appartement               Advanced    group_0
# 3      Appartement               Advanced    group_0
# 4      Appartement                 Expert    group_0
# ...            ...                    ...        ...
# 22688  Rijtjeshuis               Advanced  group_999
# 22689  Appartement               Beginner  group_999
# 22690     Woonboot               Beginner  group_999
# 22691  Rijtjeshuis               Beginner  group_999
# 22692   Vrijstaand               Beginner  group_999
#
# [22693 rows x 15 columns]

# %%
df['birthdate'] = pd.to_datetime(df['birthdate'], errors='coerce')
df['age'] = (pd.to_datetime('today') - df['birthdate']).dt.days // 365
df
# Out:
#                                                job  \
# 0                                  Systems analyst
# 1                                     Cartographer
# 2                                          Actuary
# 3                                 Location manager
# 4                       Lecturer, higher education
# ...                                            ...
# 22688                      Diagnostic radiographer
# 22689                       Programmer, multimedia
# 22690             Higher education careers adviser
# 22691  Armed forces training and education officer
# 22692                          Seismic interpreter
#
#                                 name sex  birthdate country_of_origin  \
# 0                       Kyara Oennen   F 1975-09-25           Chinees
# 1                        Guus Briere   M 2009-06-13           Chinees
# 2      Evi van de Kooij-van Grinsven   M 1999-02-24             Turks
# 3                  Ruben Cornelissen   F 1935-01-11           Indiaas
# 4                        Jort Backer   F 1940-12-03        Nederlands
# ...                              ...  ..        ...               ...
# 22688                   Yusuf Dubois   F 1924-01-27       Indonesisch
# 22689           Ibrahim van der Leek   F 1966-12-22           Chinees
# 22690   Lena van de Ven-van Engeland   M 1928-09-14        Nederlands
# 22691                 Joost Sterkman   M 1991-05-29        Nederlands
# 22692        Noah Bresse-van Stralen   M 1960-08-29             Turks
#
#       socio_economic_status      household_composition political_orientation  \
# 0                      Laag               Alleenstaand                Rechts
# 1                 Gemiddeld  Alleenstaand met kinderen                 Links
# 2                      Laag   Samenwonend met kinderen                Midden
# 3                      Laag   Samenwonend met kinderen                Midden
# 4                      Laag   Samenwonend met kinderen                 Links
# ...                     ...                        ...                   ...
# 22688                  Laag                Samenwonend                Rechts
# 22689                  Laag   Samenwonend met kinderen                 Links
# 22690             Gemiddeld   Samenwonend met kinderen                Midden
# 22691                  Laag                Samenwonend                Rechts
# 22692                  Hoog   Samenwonend met kinderen                Rechts
#
#       education_level       religion    marital_status employment_status  \
# 0                 MBO  Hindoeïstisch            Gehuwd     Gepensioneerd
# 1                  WO    Christelijk          Ongehuwd          Fulltime
# 2                HAVO    Christelijk  Weduwe/Weduwnaar       Zelfstandig
# 3                VMBO    Islamitisch          Ongehuwd          Parttime
# 4                 MBO   Geen religie            Gehuwd          Parttime
# ...               ...            ...               ...               ...
# 22688             HBO   Geen religie          Ongehuwd          Fulltime
# 22689            HAVO    Islamitisch          Ongehuwd          Parttime
# 22690             MBO    Islamitisch          Ongehuwd          Werkloos
# 22691            VMBO    Christelijk            Gehuwd          Parttime
# 22692             MBO  Boeddhistisch            Gehuwd          Fulltime
#
#       housing_type technology_proficiency      group  age
# 0      Rijtjeshuis               Advanced    group_0   49
# 1      Rijtjeshuis           Intermediate    group_0   15
# 2      Appartement               Advanced    group_0   26
# 3      Appartement               Advanced    group_0   90
# 4      Appartement                 Expert    group_0   84
# ...            ...                    ...        ...  ...
# 22688  Rijtjeshuis               Advanced  group_999  101
# 22689  Appartement               Beginner  group_999   58
# 22690     Woonboot               Beginner  group_999   96
# 22691  Rijtjeshuis               Beginner  group_999   33
# 22692   Vrijstaand               Beginner  group_999   64
#
# [22693 rows x 16 columns]

# %%
# Bijvoorbeeld: gemiddelde leeftijd per groep
avg_age_per_group = df.groupby('group')['age'].mean().sort_values(ascending=False)
print(avg_age_per_group.head(10))
# Out:
# group
# group_531    85.700000
# group_763    82.090909
# group_213    80.437500
# group_475    77.900000
# group_110    76.692308
# group_54     76.090909
# group_721    75.800000
# group_564    74.722222
# group_348    74.333333
# group_575    74.314286
# Name: age, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Zorg dat 'group' en 'sex' kolommen er zijn
if 'group' in df.columns and 'sex' in df.columns:
    plt.figure(figsize=(12, 6))
    sns.histplot(data=df, x='group', hue='sex', bins = 2000)
    plt.title("Verdeling van geslacht per groep")
    plt.xticks(rotation=90)
    plt.tight_layout()
    plt.show()

# %%
def plot_group_distribution_percent(df, column, top_n=100, sort_by_value=None):
    # Bereken % distributie per groep
    df_counts = (
        df.groupby(['group', column])
        .size()
        .groupby(level=0)
        .apply(lambda x: 100 * x / float(x.sum()))
        .unstack()
        .fillna(0)
    )

    # Alleen top N groepen op basis van groepsgrootte
    top_groups = df['group'].value_counts().head(top_n).index
    df_counts = df_counts.loc[top_groups]

    # Sorteer op specifieke waarde (bijv. 'male')
    if sort_by_value and sort_by_value in df_counts.columns:
        df_counts = df_counts.sort_values(by=sort_by_value, ascending=False)

    # Plot zonder randen tussen de balken
    df_counts = df_counts.sort_values('M', ascending=False)
    ax = df_counts.plot(kind='bar', stacked=True, colormap='tab10', edgecolor='none', width=1)

    ax.set_title(f"Gestapelde procentuele verdeling van '{column}' (top {top_n} groepen, gesorteerd op '{sort_by_value}')")
    ax.set_ylabel("Percentage")
    ax.set_xticks([])  # Verberg x-ticks
    ax.legend(title=column, bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()
    
    return df_counts


tst = plot_group_distribution_percent(df, 'sex', top_n=1000, sort_by_value='male')

# %%
import matplotlib.pyplot as plt

def plot_stack_area_chart(df, column, top_n=100):
    # Zorg ervoor dat we werken met percentage distributie per groep
    df_counts = (
        df.groupby(['group', column])
        .size()
        .groupby(level=0)
        .apply(lambda x: 100 * x / float(x.sum()))
        .unstack()
        .fillna(0)
    )

    # Alleen top N groepen op basis van groepsgrootte
    top_groups = df['group'].value_counts().head(top_n).index
    df_counts = df_counts.loc[top_groups]

    # Plotten als gestapelde gebiedsdiagram
    df_counts = df_counts.sort_values(df_counts.columns[0] ,ascending = False)
    ax = df_counts.plot(kind='area', stacked=True, figsize=(12, 6), colormap='tab10')

    ax.set_title(f"Gestapelde gebiedsdiagram van '{column}' (top {top_n} groepen)")
    ax.set_ylabel("Percentage")
    ax.set_xlabel("Groep")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

    return df_counts
tst = plot_stack_area_chart(df, 'household_composition', 1000)

# %%
tst.columns[0]
# Out:
# 'Gemiddeld'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

def plot_aggregated_stack_area(
    df: pd.DataFrame,
    group_col: str,          # Column name for groups (e.g., 'group')
    category_col: str,       # Column name for categories (e.g., 'household_composition')
    top_n: int = 1000,       # Number of top groups (by count) to consider
    num_bins: int = 20,      # How many bins to aggregate into
    sort_by_category: str = None, # Which category percentage to sort by before binning
    sort_ascending: bool = False, # Sort order (False = descending)
    figsize: tuple = (12, 6),
    colormap: str = 'tab10'
):
    """
    Generates and displays an aggregated stacked area chart.

    Calculates category percentages within groups, filters for top N groups,
    sorts them by a specified category's percentage, aggregates into bins,
    and plots the average composition per bin.

    Args:
        df (pd.DataFrame): Input DataFrame with raw data.
        group_col (str): Name of the column containing group identifiers.
        category_col (str): Name of the column containing the categories to stack.
        top_n (int, optional): Consider only the top N groups based on their
                               total count in `df`. Defaults to 1000.
        num_bins (int, optional): Number of bins to aggregate the sorted groups
                                  into for plotting. Defaults to 20.
        sort_by_category (str, optional): The category name (value within
                                          `category_col`) whose percentage
                                          should be used for sorting groups
                                          before binning. If None, defaults to
                                          the first category found. Defaults to None.
        sort_ascending (bool, optional): Sort order for `sort_by_category`.
                                         Defaults to False (descending).
        figsize (tuple, optional): Figure size. Defaults to (12, 6).
        colormap (str, optional): Colormap for the plot. Defaults to 'tab10'.

    Returns:
        pd.DataFrame: The aggregated DataFrame used for plotting (average
                      percentages per bin). Returns None if plotting fails.

    Raises:
        ValueError: If specified columns or sort category are not found, or
                    if num_bins is invalid.
    """
    # --- Input Validation ---
    if group_col not in df.columns:
        raise ValueError(f"Group column '{group_col}' not found in DataFrame.")
    if category_col not in df.columns:
        raise ValueError(f"Category column '{category_col}' not found in DataFrame.")

    # --- 1. Calculate Percentage Distribution per Group ---
    try:
        df_percentages = (
            df.groupby([group_col, category_col])
            .size()
            .groupby(level=0) # Group by group_col index
            .apply(lambda x: 100 * x / float(x.sum()))
            .unstack(fill_value=0) # Pivot categories to columns, fill missing with 0
        )
    except ZeroDivisionError:
        print("Warning: Some groups might have zero total counts, leading to division by zero.")
        # Handle potentially empty groups if necessary, e.g., by filtering them out first.
        # For now, we proceed, unstack(fill_value=0) handles groups with some categories missing.
        # Re-calculate potentially filtering groups with zero total counts if it causes issues.
        group_counts = df.groupby(group_col).size()
        valid_groups = group_counts[group_counts > 0].index
        df_filtered = df[df[group_col].isin(valid_groups)]
        if df_filtered.empty:
             print("Error: No valid groups with counts > 0 found.")
             return None
        df_percentages = (
            df_filtered.groupby([group_col, category_col])
            .size()
            .groupby(level=0)
            .apply(lambda x: 100 * x / float(x.sum()))
            .unstack(fill_value=0)
        )


    if df_percentages.empty:
        print("Warning: Percentage DataFrame is empty after calculations.")
        return None

    # --- 2. Filter for Top N Groups (Optional) ---
    if top_n is not None and top_n < len(df_percentages):
        # Get top N groups based on total count in original df
        top_groups_by_count = df[group_col].value_counts().head(top_n).index
        # Filter the percentage dataframe - use intersection for safety
        valid_top_groups = df_percentages.index.intersection(top_groups_by_count)
        df_percentages = df_percentages.loc[valid_top_groups]
        if df_percentages.empty:
             print(f"Warning: No groups remaining after filtering for top {top_n}.")
             return None


    actual_num_groups = len(df_percentages)
    if actual_num_groups == 0:
        print("Warning: DataFrame is empty after filtering. Cannot generate plot.")
        return None

    # --- 3. Sort Groups ---
    actual_categories = df_percentages.columns.tolist()
    if sort_by_category is None:
        sort_by_category = actual_categories[0] # Default to first column
        print(f"Warning: No 'sort_by_category' specified. Sorting by first category found: '{sort_by_category}'")
    elif sort_by_category not in actual_categories:
        raise ValueError(f"Category '{sort_by_category}' specified for sorting not found "
                         f"in calculated percentage columns: {actual_categories}")

    df_sorted = df_percentages.sort_values(by=sort_by_category, ascending=sort_ascending)
    # Reset index here so we can assign bins based on row number easily
    df_sorted = df_sorted.reset_index(drop=True)


    # --- 4. Create Bins and Aggregate ---
    num_bins = min(num_bins, actual_num_groups) # Cannot have more bins than groups
    if num_bins <= 0:
        raise ValueError("Number of bins must be positive.")

    groups_per_bin = actual_num_groups // num_bins

    # Create an array indicating which bin each row (sorted group) belongs to
    bin_assignments = np.repeat(np.arange(num_bins), groups_per_bin)

    # Distribute remainder groups more evenly across the last bins
    remainder = actual_num_groups % num_bins
    if remainder > 0:
        extras = np.repeat(np.arange(num_bins - remainder, num_bins), 1)
        bin_assignments = np.concatenate([bin_assignments, extras])

    # Ensure bin_assignments has the correct length (important if remainder was 0)
    bin_assignments = bin_assignments[:actual_num_groups]

    df_sorted['bin'] = bin_assignments

    # Calculate the average percentage for each original category within each bin
    df_agg = df_sorted.groupby('bin')[actual_categories].mean()

    # --- 5. Create Bin Labels ---
    bin_labels = []
    start_idx = 0
    for i in range(num_bins):
        # Find the last index (in the sorted df) belonging to the current bin
        end_idx = df_sorted[df_sorted['bin'] == i].index.max()
        if pd.isna(end_idx): continue # Skip if a bin ended up empty

        # Label includes bin number and range of sorted indices it covers
        bin_labels.append(f"Bin {i+1}\n(Sorted Idx {start_idx}-{int(end_idx)})")
        start_idx = int(end_idx) + 1

    # --- 6. Plot the Aggregated Data ---
    fig, ax = plt.subplots(figsize=figsize)
    df_agg.plot(kind='area', stacked=True, ax=ax, colormap=colormap)

    # --- 7. Customize Plot ---
    sort_order_desc = "Descending" if not sort_ascending else "Ascending"
    title = (f"Aggregated Stacked Area Chart of '{category_col}' ({num_bins} Bins)\n"
             f"({actual_num_groups} Groups from Top {top_n if top_n else 'All'}, "
             f"Sorted by % {sort_by_category} {sort_order_desc})")
    ax.set_title(title)
    ax.set_ylabel("Average Percentage (%)")
    ax.set_xlabel("Group Bins (based on sorted order)")

    # Set x-axis ticks and labels
    #ax.set_xticks(np.arange(len(bin_labels))) # Use number of labels generated
    ax.set_xticklabels(bin_labels, rotation=45, ha='right') # Apply bin labels

    # Set y-axis limits and format
    ax.set_ylim(0, 100)
    ax.yaxis.set_major_formatter(mticker.PercentFormatter(xmax=100.0))

    # Add Legend
    ax.legend(title=category_col, loc='center left', bbox_to_anchor=(1, 0.5))

    # Adjust layout
    plt.tight_layout(rect=[0, 0, 0.85, 1]) # Make space for legend
    plt.show()

    return df_agg

# %%
col_list = ['country_of_origin', 'socio_economic_status', 'household_composition',
            'political_orientation', 'education_level', 'religion', 'marital_status', 'employment_status',
            'housing_type', 'technology_proficiency']
for col_name in col_list:
    plot_aggregated_stack_area(
    df=df,
    group_col='group',                 # Your column with group names
    category_col=col_name, # Your column with categories
    top_n=1000,                        # How many top groups to analyze
    num_bins=25,                       # How many bins for the final plot x-axis
    sort_ascending=False               # Show highest % of 'Alleenstaand' on the left
)
# Out:
# Warning: No 'sort_by_category' specified. Sorting by first category found: 'Antilliaans'
# C:\Users\caspe\AppData\Local\Temp\ipykernel_29440\3911589663.py:171: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(bin_labels, rotation=45, ha='right') # Apply bin labels
# Warning: No 'sort_by_category' specified. Sorting by first category found: 'Gemiddeld'
# C:\Users\caspe\AppData\Local\Temp\ipykernel_29440\3911589663.py:171: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(bin_labels, rotation=45, ha='right') # Apply bin labels
# Warning: No 'sort_by_category' specified. Sorting by first category found: 'Alleenstaand'
# C:\Users\caspe\AppData\Local\Temp\ipykernel_29440\3911589663.py:171: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(bin_labels, rotation=45, ha='right') # Apply bin labels
# Warning: No 'sort_by_category' specified. Sorting by first category found: 'Links'
# C:\Users\caspe\AppData\Local\Temp\ipykernel_29440\3911589663.py:171: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(bin_labels, rotation=45, ha='right') # Apply bin labels
# Warning: No 'sort_by_category' specified. Sorting by first category found: 'Basisonderwijs'
# C:\Users\caspe\AppData\Local\Temp\ipykernel_29440\3911589663.py:171: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(bin_labels, rotation=45, ha='right') # Apply bin labels
# Warning: No 'sort_by_category' specified. Sorting by first category found: 'Anders'
# C:\Users\caspe\AppData\Local\Temp\ipykernel_29440\3911589663.py:171: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(bin_labels, rotation=45, ha='right') # Apply bin labels
# Warning: No 'sort_by_category' specified. Sorting by first category found: 'Gehuwd'
# C:\Users\caspe\AppData\Local\Temp\ipykernel_29440\3911589663.py:171: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(bin_labels, rotation=45, ha='right') # Apply bin labels
# Warning: No 'sort_by_category' specified. Sorting by first category found: 'Fulltime'
# C:\Users\caspe\AppData\Local\Temp\ipykernel_29440\3911589663.py:171: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(bin_labels, rotation=45, ha='right') # Apply bin labels
# Warning: No 'sort_by_category' specified. Sorting by first category found: 'Appartement'
# C:\Users\caspe\AppData\Local\Temp\ipykernel_29440\3911589663.py:171: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(bin_labels, rotation=45, ha='right') # Apply bin labels
# Warning: No 'sort_by_category' specified. Sorting by first category found: 'Advanced'
# C:\Users\caspe\AppData\Local\Temp\ipykernel_29440\3911589663.py:171: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(bin_labels, rotation=45, ha='right') # Apply bin labels
